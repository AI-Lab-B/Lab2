# %%
import pandas as np
import matplotlib.pyplot as plt

# %%
#Q1
group_A = np.array([12, 15, 14, 13, 16, 18, 19, 15, 14, 20, 17, 14, 15,8])
group_B = np.array([12, 17, 15, 13, 19, 20, 21, 18, 17, 16, 15, 14, 16, 15])

plt.subplot(2, 1, 1)
plt.plot(group_A,group_B)

plt.subplot(2, 1, 2)
plt.plot(group_A,group_B)

# %%
fig = plt.figure(figsize =(10, 7))
plt.boxplot(group_B)

plt.show()
fig = plt.figure(figsize =(10, 7))
plt.boxplot([group_A,group_B],labels=['group_A','group_B'])
plt.xlabel('X');
plt.ylabel('Y');

# show plot
plt.show()
# Out:
# <ipython-input-3-89a79454ce3f>:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([group_A,group_B],labels=['group_A','group_B'])

# %%
#Q2
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


file = open('/content/sample_data/file.txt', 'r')
content = file.read()

L = list(content.strip())
g = len(L)
genome = "".join(random.choice(L) for _ in range(g))
t = np.linspace(0, 4 * np.pi, g)
x = np.cos(t)
y = np.sin(t)
z = np.linspace(0, 5, g)
coordinates = np.column_stack((x, y, z))

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('3D Scatter Plot')

plt.show()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

image = Image.open('/content/sample_data/download.jfif')
img_array = np.array(image)

plt.imshow(img_array)
plt.title('Original Image')
plt.show()

rotated_img = np.rot90(img_array)
plt.imshow(rotated_img)
plt.title('Rotated Image')
plt.show()

flipped_img = np.flip(img_array, axis=0)
plt.imshow(flipped_img)
plt.title('Flipped Image')
plt.show()

gray_img = np.dot(img_array[..., :3], [0.299, 0.587, 0.114])

grayscale = np.mean(img_array, axis=2)
plt.imshow(grayscale, cmap='gray')
plt.title('Grayscale Image')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

iris = load_iris()
X = np.array(iris.data)
Y = np.array(iris.target)

mean_values = np.mean(X, axis=0)
median_values = np.median(X, axis=0)
std_dev_values = np.std(X, axis=0)
min_values = np.min(X, axis=0)
max_values = np.max(X, axis=0)

sepal_data = X[:, :2]

print("Mean:", mean_values)
print("Median:", median_values)
print("Standard Deviation:", std_dev_values)
print("Min Values:", min_values)
print("Max Values:", max_values)

plt.figure(figsize=(6, 4))
plt.scatter(X[:, 0], X[:, 1], c=Y, cmap='viridis', edgecolors='k')
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("Scatter Plot: Sepal Length vs Sepal Width")
plt.colorbar(label="Species")
plt.show()

plt.figure(figsize=(6, 4))
plt.hist(X[:, 0], bins=15, color='blue', edgecolor='black', alpha=0.7)
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.title("Histogram of Sepal Length")
plt.show()

plt.figure(figsize=(6, 4))
plt.plot(X[:, 2], X[:, 3], marker='o', linestyle='-', color='red')
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Line Plot: Petal Length vs Petal Width")
plt.show()
# Out:
# Mean: [5.84333333 3.05733333 3.758      1.19933333]
# Median: [5.8  3.   4.35 1.3 ]
# Standard Deviation: [0.82530129 0.43441097 1.75940407 0.75969263]
# Min Values: [4.3 2.  1.  0.1]
# Max Values: [7.9 4.4 6.9 2.5]
